# %%
import sqlite3
con = sqlite3.connect("JudicialAnalysis.db")

cur = con.cursor()

# %%
# 創建 Table
new = 0
if new:
    cur.execute("CREATE TABLE results(jid, date, law, keyword_type, keywords)")
    con.commit()
    con.close()

# %%
from ElementExtractor import Judicial_Parser
import os, time, traceback, json, re

# %%
from ckiptagger import data_utils, construct_dictionary, WS, POS, NER

# %%
# Downloads to ./data.zip (2GB) and extracts to ./data/
# data_utils.download_data_url("./") # iis-ckip
#data_utils.download_data_gdown("./") # gdrive-ckip 已下載就不用再下載

# %%
# To use GPU:
#    1. Install tensorflow-gpu (see Installation)
#    2. Set CUDA_VISIBLE_DEVICES environment variable, e.g. os.environ["CUDA_VISIBLE_DEVICES"] = "0"
#    3. Set disable_cuda=False, e.g. ws = WS("./data", disable_cuda=False)

# 採坑心得
# 新版已經沒有 tensorflow-gpu
# 我使用 python 3.7 的環境 (conda create -n ckipcore python=3.7)
# 先安裝 pip install -U ckiptagger[tf,gdown]
# 再改用 Conda install tensorflow 去安裝匹配的新版
# 搭配 disable_cuda=False 參數，從 windows 工作管理員之效能頁籤看起來，確實有使用 GPU

ws = WS("./data", disable_cuda=False)
pos = POS("./data", disable_cuda=False)
ner = NER("./data", disable_cuda=False)
# Out:
# C:\ProgramData\Anaconda3\envs\ckipcore\lib\site-packages\ckiptagger\model_ws.py:106: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)
# C:\ProgramData\Anaconda3\envs\ckipcore\lib\site-packages\ckiptagger\model_pos.py:56: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)
# C:\ProgramData\Anaconda3\envs\ckipcore\lib\site-packages\ckiptagger\model_ner.py:57: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)

# %%
# 簡繁轉換器 (暫時用不到)
# import opencc
# converter = opencc.OpenCC('t2s.json')

# %%
from IPython.display import clear_output

start_time = time.time()
print(f'[現在時間] {time.strftime("%Y-%m-%d %H:%M:%S")}')

source_file = os.path.join(
        'C:\\', '課程', '交大','論文','案件整理',
        'json_files.txt'
        )
    
count_file_done_num = 0
clear_output()
print('-'*50)
print(f'>>開始分析...')
print(f'[當前已分析數量] {count_file_done_num}')

with open(source_file, 'r', encoding='utf-8') as f:
    # 2022~2023年判決書有211萬7,454個json檔
    # 故一次讀一個處理，減少記憶體占用
    raw_data = ''
    
    while 1: 
        # 開始逐案讀取資料分析
        file = f.readline()
        if '\\2023' in file: # 因為數量太多要跑太久，先從2023開始好了
            count_file_done_num += 1

            if '刑事' in file:
                # 篩掉一些比較非刑案的
                if not ('簡易' in file or '民事' in file or '補償' in file or '憲法' in file or '商業' in file):
                    # 開始讀取裁判書內容
                    file = file.strip()

                    # 顯示進度
                    temp_time = time.time()
                    elapsed_time = temp_time - start_time
                    hours = int(elapsed_time // 3600)  # 計算小時數
                    minutes = int((elapsed_time % 3600) // 60)  # 計算分鐘數
                    seconds = int(elapsed_time % 60)  # 計算剩餘秒數

                    clear_output()
                    print('-'*50)
                    print(f'>>開始分析...')
                    print(f'[當前已分析數量] {count_file_done_num}')
                    print(f'[累計耗時] {hours}:{minutes}:{seconds}')
                    print(f'[當前檔案] {file}')

                    # 確定 file 存在
                    if not os.path.isfile(file):
                        print(f'[並非正常檔案] 跳過...')
                        time.sleep(1)
                        continue

                    with open(file, 'r', encoding='utf-8') as jf:
                        json_data = json.load(jf)

                    # 資料清洗
                    parser = Judicial_Parser(json_data)

                    jid = parser.jid.strip().replace(' ', '')
                    date = parser.dateSTR.strip().replace(' ', '')
                    raw = parser.raw
                    text = parser.text
                    text_u = parser.text_u

                    # 確定是否已經在資料庫內
                    check_res = cur.execute(f"SELECT jid FROM results WHERE jid='{jid}'")
                    temp = check_res.fetchone()
                    if temp:
                        print(f'[JID] {jid}')
                        print('>>此JID發現資料庫已有，跳過')
                        continue

                    # 沒有在資料庫內才處理
                    # Input text
                    print('[WS] 分析中')
                    sentence_list = text_u.split('。')
                    word_sentence_list = ws(
                        sentence_list,
                        # sentence_segmentation = True, # To consider delimiters
                        # segment_delimiter_set = {",", "。", ":", "?", "!", ";"}), # This is the defualt set of delimiters
                        # recommend_dictionary = dictionary1, # words in this dictionary are encouraged
                        # coerce_dictionary = dictionary2, # words in this dictionary are forced
                    )
                    print('[POS] 分析中')
                    pos_sentence_list = pos(word_sentence_list)
                    print('[NER] 分析中')
                    entity_sentence_list = ner(word_sentence_list, pos_sentence_list)

                    # 用 POS 區分的類型
                    type_dict = dict()
                    for idx, words in enumerate(word_sentence_list):
                        for idx2, w in enumerate(words):
                            temp_type = pos_sentence_list[idx][idx2]
                            type_dict.setdefault(temp_type, set())
                            type_dict[temp_type].add(w)

                    # 經人工檢查，N(名詞)比較符合需要的有
                    # 'Na', 'Nb'
                    type_N = [t for t in type_dict.keys() if t.startswith('N')]
                    type_N.sort()
                    for n in type_N:
                        print('-'*50)
                        print(f'TYPE: {n}')
                        print(type_dict[n])

                    # 經人工檢查，V(動詞)比較符合需要的有
                    # 'VA', 'VC', 'VD, 'VH', 
                    type_V = [t for t in type_dict.keys() if t.startswith('V')]
                    type_V.sort()
                    for v in type_V:
                        print('-'*50)
                        print(f'TYPE: {v}')
                        print(type_dict[v])

                    # 擷取法條
                    laws = set()
                    for e in entity_sentence_list:
                        for ee in e:
                            if ee[2] == 'LAW':
                                laws.add(ee[3])
                    print('-'*50)
                    print('TYPE: LAW')
                    print(laws)

                    if not laws:
                        print('>>此篇未發現 law 犯罪條文，跳過')
                        continue

                    # 寫入 Table
                    print('-'*50)
                    print('>>準備寫入 Table')
                    # results(jid, date, law, keyword_type, keywords)

                    for law in laws:
                        # 初步處理一下 law 標準化
                        law = law.strip().replace(' ', '').upper()

                        # 先從名詞，再來動詞
                        type_range = ['Na', 'Nb', 'VA', 'VC', 'VD', 'VH']
                        for tr in type_range:
                            print('-'*50)
                            print(f'>>準備寫入 {tr}')
                            if tr in type_dict:
                                na_set = {n.strip().replace(' ', '') for n in type_dict[tr] if len(n.strip().replace(' ', '')) > 1}
                                # 發現結果都會有很多,,,可能是 n 裡面本來就有 ,
                                # 所以先轉換一次，去除以後再存
                                na_set = ','.join(na_set).split(',')
                                na_set = [n.upper() for n in na_set if n]
                                na_set = list(set(na_set)) # 去除重複
                                na_set.sort()
                                na_strs = ','.join(na_set).strip().replace(' ', '')
                                while ',,' in na_strs:
                                    na_strs = na_strs.replace(',,', ',')
                                to_db_content = f"INSERT INTO results VALUES('{jid}', '{date}', '{law}', '{tr}', '{na_strs}')".strip().replace(':')
                                cur.execute(to_db_content)
                        con.commit()

                        print('-'*50)
                        print('>>完成!!!')
                    
con.close()
end_time = time.time()
elapsed_time = end_time - start_time
hours = int(elapsed_time // 3600)  # 計算小時數
minutes = int((elapsed_time % 3600) // 60)  # 計算分鐘數
seconds = int(elapsed_time % 60)  # 計算剩餘秒數
print(f'[累計耗時] {hours}:{minutes}:{seconds}')
# Out:
# --------------------------------------------------
# >>開始分析...
# [當前已分析數量] 11404
# [累計耗時] 0:0:30
# [當前檔案] C:\課程\交大\論文\案件整理\202301\臺灣嘉義地方法院刑事\CYDM,112,金簡,14,20230131,1.json
# [WS] 分析中
# [POS] 分析中
# [NER] 分析中
# --------------------------------------------------
# TYPE: Na
# {'內涵', '類型', '合理性', '集團', '自由', '量', '勞力', '犯行', '手', '地方', '政府', '關聯性', '法', '證券', '財物', '學理', '文字', '行為人', '競合犯', '憑條', '國家', '機構', '智識', '關係', '罰則', '體系', '通念', '經濟', '規定', '商業', '稅籍', '訊息', '來源', '帳號', '核', '附件', '基礎', '徒', '帳戶犯', '意旨', '專員', '情況', '事件', '案件', '物', '記載', '錯誤', '年籍', '者', '大字', '職務', '利得', '現狀', '利益', '資料', '字', '紀錄', '罪', '己意', '軌跡', '財產', '嗣', '證明聯', '本刑', '契約書', '常識', '罪名', '程序', '資金', '一般人', '社會', '責任', '匯款', '手法', '人', '網際網路', '平台', '詐術', '事實欄', '金融', '警方', '所在', '第三人', '工具', '對話', '事', '影本', '成員會', '情形', '程序法', '書記官', '意思', '罪嫌', '刑法', '態度', '日期', '助力', '原則', '之罪', '交易', '本意', '情', '金流', '損失', '被害人', '新臺幣', '上情', '手段', '委託書', '勞役', '刑', '要件', '法官', '密碼', '帳戶', '犯嫌', '犯意', '事務官', '期間', '階段', '本案', '通訊', '告訴人', '情狀', '業據', '理由', '標準', '語', '警察', '截圖', '勞務', '困擾', '訴訟法', '金訴字', '舉', '秩序', '所得', '價額', '卷', '案', '保障', '生活', '用途', '機關', '去向', '動機', '孳息', '目的', '行動', '物品', '證明', '人士', '本質', '事實', '歪風', '頁面', '專有性', '有期徒刑', '危害', '所有權', '犯罰', '上開', '報告', '提款卡', '取財罪', '正犯', '金簡字', '存摺', '附錄', '限制', '被告', '金額', '形式', '偵字', '明細', '報酬', '經驗', '工作', '狀況', '法條', '內容', '證據', '自白', '起訴書', '檢察官', '名義', '成員', '程度', '軟體', '星期', '處分權', '公眾', '附繕本', '罰金', '網路', '職業', '反面', '上訴狀', '細節', '主文', '重論', '洗錢罪', '罪疑', '風氣', '正本', '拘役', '客服', '薪資', '幫助犯', '權益', '姓名', '上述', '效果', '刑事', '能力', '方式', ',委', '行為'}
# --------------------------------------------------
# TYPE: Nb
# {'陳智識', '李芷庭', '葉芳如', '林家賢', '江金星', '貝萊德', '黃天儀', '綦詳', '富邦', '林書慧', '羅佳昇', '胡銓祐'}
# --------------------------------------------------
# TYPE: Nc
# {'檢察署', '院', '臺北市', '我國', '台', '署', '幕後', '岡山', '中華民國', '法院', '處', '警察局', '○○區', '嘉義', '○○○路', '000號', '附近', '分局', '簡易庭', '高雄市', '銀行', '最高法院', '台北', '合議庭', '臺灣'}
# --------------------------------------------------
# TYPE: Ncd
# {'上', '中', '下'}
# --------------------------------------------------
# TYPE: Nd
# {'壹日', '5日', '嗣', '6月', '18時', '108年度', '19時', '當日', '111年', '8日', '13時', '41分', '111年度', '89年度', '10日', '112年度', '茲', '1月', '112年', '同時', '14日', '5分', '31日', '14時', '民國', '52分', '1日', '3月', '5月'}
# --------------------------------------------------
# TYPE: Nep
# {'此', '其'}
# --------------------------------------------------
# TYPE: Neqa
# {'一切', '所有', '其餘', '任何', '其他', '部分', '多數'}
# --------------------------------------------------
# TYPE: Neqb
# {'許'}
# --------------------------------------------------
# TYPE: Nes
# {'該', '諸', '本', '同', '前', '另', '各', '何'}
# --------------------------------------------------
# TYPE: Neu
# {'第339', '4', '1', '第454', '00000000000', '2', '第3', '第6946', '第449', '第1', '第二', '第14', '5', '第9', '第41', '壹萬', '第251', '乙', '7', '第3101', '(七)', '第55', '20', '二', '第16', '第17', '第15', '第十四', '第2', '(一)', '第30', '5百萬', '(六)', '50萬', '第一', '一', '三', '六', '31', '000', '15萬', '壹仟', ' 一', '第12773'}
# --------------------------------------------------
# TYPE: Nf
# {'元', '件', '種', '歲', '天', '號', '年', '條', '行', '個', '項', '段', '款', '日'}
# --------------------------------------------------
# TYPE: Ng
# {'時', '而言', '之前', '上', '以外', '外', '起', '內', '間', '後', '以下'}
# --------------------------------------------------
# TYPE: Nh
# {'大眾', '之', '自己', '個人', '他人', '對方', '吾人', '本人', '別人'}
# --------------------------------------------------
# TYPE: Nv
# {'犯罪', '構成', '配合', '住宿'}
# --------------------------------------------------
# TYPE: VA
# {'報警', '犯資', '流通', '斷點', '立法', '回流', '到庭', '臨櫃', '兼職', '流動', '理財', '洗錢', '生活', '取款', '追訴', '犯罪', '參月', '取財', '轉帳', '賺錢', '北上', '開戶'}
# --------------------------------------------------
# TYPE: VB
# {'自白', '論罪', '提起公訴', '處刑', '詐財', '加工', '匯款'}
# --------------------------------------------------
# TYPE: VC
# {'逃避', '幫助', '收購', '害', '調解', '制止', '衡酌', '偵辦', '沒收', '處理', '實現', '領', '開立', '綁定', '犯', '配合', '隔絕', '詐欺', '移轉', '取得', '併科', '引用', '告', '翻新', '達成', '領得', '記載', '定', '收受', '上', '控制', '警詢', '觀', '詐取', '轉換', '登記', '追查', '切斷', '申設', '縱將', '掩飾', '包裝', '加重', '利用', '認', '開', '並利', '投資', '處罰', '成立', '追緝', '體察', '收取', '遮斷', '準備', '提領', '聯絡', '審酌', '計算', '獨任', '提出', '判處', '憑添', '處', '論', '製造', '追徵', '闡明', '參與', '上揭', '使用', '賺取', '處置', '整合', '科', '易科', '採', '申辦', '聯結', '列', '用', '上訴', '借用', '實行', '付出', '爰', '附', '補充', '易服', '訴', '保管', '執行', '邀集', '終結', '縱', '偵查', '變更', '隱匿', '分敘'}
# --------------------------------------------------
# TYPE: VCL
# {'用於', '落入'}
# --------------------------------------------------
# TYPE: VD
# {'送達', '轉匯', '提供', '提供予', '交給', '予', '交付', '詐騙', '賠償', '補償', '傳送', '遞', '層轉'}
# --------------------------------------------------
# TYPE: VE
# {'指定', '查悉', '防止', '防制', '示', '裁定', '約定', '詢問', '查詢', '見', '解釋', '防範', '判決', '規定', '宣告', '告知', '認', '承', '指訴', '稽', '認定', '觀察', '諭知', '預見', '明示', '敘明', '證明', '辯稱', '查', '訊問', '坦承', '辯', '公示', '併諭'}
# --------------------------------------------------
# TYPE: VF
# {'申請', '請求', '受命', '請', '交由', '要求', '供', '意圖'}
# --------------------------------------------------
# TYPE: VG
# {'做為', '更正為', '乃', '即', '暱稱為', '造成', '成為', '指', '構成', '暱稱', '屬', '係為', '併為', '作為', '分成', '利用為', '稱', '為', '折算', '有妥為', '係'}
# --------------------------------------------------
# TYPE: VH
# {'紊亂', '重', '良好', '客觀', '自由', '親密', '主觀', '不同', '不足', '散布', '互信', '猖獗', '繁多', '真實', '簡易', '實', '即可', '相關', '不明', '積極', '乙情不諱', '難', '無疑', '特殊', '困難', '易', '年幼', '正常', '相識', '合作', '深入', '相繩', '無知', '無聊', '防不勝防', '迂迴', '不詳', '具體', '層出不窮', '合理', '複雜', '未遂', '高', '好', '合法', '化整為零', '直接', '受損', '有異', '沒關係', '核其所為'}
# --------------------------------------------------
# TYPE: VHC
# {'去化', '分層化', '產生', '減輕', '多層化', '空'}
# --------------------------------------------------
# TYPE: VI
# {'所有'}
# --------------------------------------------------
# TYPE: VJ
# {'服', '包含', '同', '以利', '獲', '受有', '違反', '違背', '適用', '持有', '認識', '認知', '觸犯', '參照', '變得', '具備', '有所', '無', '精簡', '超過', '有關', '認應', '陷於', '得', '為', '獲得', '享受', '關'}
# --------------------------------------------------
# TYPE: VK
# {'造成', '瞭解', '想像', '知', '不服', '知悉', '須', '如下', '發覺', '深知', '歸於', '助長', '無異', '所謂', '在於'}
# --------------------------------------------------
# TYPE: VL
# {'致', '足以', '故意', '令', '執意', '不予', '堪', '使'}
# --------------------------------------------------
# TYPE: V_2
# {'有'}
# --------------------------------------------------
# TYPE: LAW
# {'第449條', '刑法', '刑事訴訟法', '洗錢防制法'}
# --------------------------------------------------
# >>準備寫入 Table
# --------------------------------------------------
# >>準備寫入 Na
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7868\1178158914.py in <module>
#     153                                 while ',,' in na_strs:
#     154                                     na_strs = na_strs.replace(',,', ',')
# --> 155                                 to_db_content = f"INSERT INTO results VALUES('{jid}', '{date}', '{law}', '{tr}', '{na_strs}')".strip().replace(':')
#     156                                 cur.execute(to_db_content)
#     157                         con.commit()
#
# TypeError: replace() takes at least 2 arguments (1 given)
